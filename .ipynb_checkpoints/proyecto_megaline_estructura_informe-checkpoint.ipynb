# %% [markdown]
# # 1. NOMBRE DEL PROYECTO
# ## Recomendación de Plan Telefónico — Megaline (Smart vs Ultra)

# %% [markdown]
# ---
# # 2. OBJETIVO
# Desarrollar un modelo de clasificación que recomiende el plan correcto (**Smart** o **Ultra**) a los clientes de Megaline, basándose en su comportamiento de uso (llamadas, mensajes y datos).

# %% [markdown]
# ---
# # 3. DESCRIPCIÓN DEL DATASET
# Describe aquí las columnas del dataset, qué representa cada una y cuántos registros contiene.

# %% [markdown]
# ---
# # 4. PREPARACIÓN DE DATOS

# %% [markdown]
# ## 4.1 Importar Librerías

# %%
# < importa aquí las librerías necesarias >

# %% [markdown]
# ## 4.2 Cargar el Dataset

# %%
# < carga aquí el archivo CSV >

# %% [markdown]
# ## 4.3 Exploración Inicial de los Datos

# %%
# < explora el dataset: head(), info(), describe() >

# %% [markdown]
# ## 4.4 Verificar Valores Ausentes y Duplicados

# %%
# < verifica valores nulos y duplicados >

# %% [markdown]
# ---
# # 5. DIVISIÓN DE DATOS

# %% [markdown]
# ## 5.1 Separar Características (Features) y Objetivo (Target)

# %%
# < separa las columnas de entrada (features) y la columna objetivo (target) >

# %% [markdown]
# ## 5.2 Dividir en Conjunto de Entrenamiento, Validación y Prueba

# %%
# < divide los datos: 60% entrenamiento, 20% validación, 20% prueba >

# %% [markdown]
# ---
# # 6. ENTRENAMIENTO Y EVALUACIÓN DE MODELOS

# %% [markdown]
# ## 6.1 Árbol de Decisión

# %%
# < entrena y evalúa el modelo de Árbol de Decisión >

# %% [markdown]
# ## 6.2 Bosque Aleatorio

# %%
# < entrena y evalúa el modelo de Bosque Aleatorio >

# %% [markdown]
# ## 6.3 Regresión Logística

# %%
# < entrena y evalúa el modelo de Regresión Logística >

# %% [markdown]
# ---
# # 7. SELECCIÓN DEL MEJOR MODELO

# %% [markdown]
# ## 7.1 Comparación de Resultados

# %%
# < compara la exactitud (accuracy) de los 3 modelos >

# %% [markdown]
# ## 7.2 Modelo Seleccionado y Justificación

# %% [markdown]
# Escribe aquí cuál modelo tuvo mejor desempeño y por qué lo seleccionas.

# %% [markdown]
# ---
# # 8. PRUEBA FINAL DEL MODELO

# %% [markdown]
# ## 8.1 Evaluación con el Conjunto de Prueba

# %%
# < evalúa el mejor modelo con el conjunto de prueba >

# %% [markdown]
# ## 8.2 Verificación del Umbral de Exactitud (accuracy ≥ 0.75)

# %%
# < verifica si el modelo supera el umbral mínimo de exactitud de 0.75 >

# %% [markdown]
# ---
# # 9. CONCLUSIONES
# Escribe aquí las conclusiones del proyecto:
# - ¿Qué modelo fue el mejor?
# - ¿Superó el umbral de exactitud requerido?
# - ¿Qué variables fueron más importantes para predecir el plan?
# - ¿Qué recomendarías a Megaline?
